# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# crack failure
df1 = pd.read_csv("/Users/leonardoroman/Desktop/data_science_projects/capstone/CRAC_12_Failure_Data_65F_supply_air_temp.csv")

# stedy state
df2 = pd.read_csv("/Users/leonardoroman/Desktop/data_science_projects/capstone/Steady_State_Data_77_supply_air_temp.csv")

# Transient state
df3 = pd.read_csv("/Users/leonardoroman/Desktop/data_science_projects/capstone/Transient_Data_77F_supply_air_temp.csv")

# %%
# Crac unit 12 failed at 65F ( 18.46C )?
df1.head(5)
#df1.tail()
#df1.describe()
# Out:
#               Unnamed: 0  Max Temperature In C
# 0  A4:Capacity Planning0                 18.46
# 1  A4:Capacity Planning1                 18.44
# 2  A4:Capacity Planning2                 18.43
# 3  A4:Capacity Planning3                 18.43
# 4  A4:Capacity Planning4                 18.43

# %%
i = 0
while ( i < 43):
    print(df2.iloc[[i]])
    i += 1
# Out:
#               Unnamed: 0  Max Temperature In C
# 0  A4:Capacity Planning0                 25.16
#               Unnamed: 0  Max Temperature In C
# 1  A4:Capacity Planning1                 25.13
#               Unnamed: 0  Max Temperature In C
# 2  A4:Capacity Planning2                 25.13
#               Unnamed: 0  Max Temperature In C
# 3  A4:Capacity Planning3                 25.13
#               Unnamed: 0  Max Temperature In C
# 4  A4:Capacity Planning4                 25.13
#               Unnamed: 0  Max Temperature In C
# 5  A4:Capacity Planning5                 25.13
#               Unnamed: 0  Max Temperature In C
# 6  A4:Capacity Planning6                 25.13
#               Unnamed: 0  Max Temperature In C
# 7  A4:Capacity Planning7                 25.14
#               Unnamed: 0  Max Temperature In C
# 8  A4:Capacity Planning8                 25.14
#               Unnamed: 0  Max Temperature In C
# 9  A4:Capacity Planning9                 25.14
# ...

# %%
# But steady at 77F ( 25.15C )!
df2.head(800)
#df2.tail()
#df2.describe()
# Out:
#                  Unnamed: 0  Max Temperature In C
# 0     A4:Capacity Planning0                 25.16
# 1     A4:Capacity Planning1                 25.13
# 2     A4:Capacity Planning2                 25.13
# 3     A4:Capacity Planning3                 25.13
# 4     A4:Capacity Planning4                 25.13
# 5     A4:Capacity Planning5                 25.13
# 6     A4:Capacity Planning6                 25.13
# 7     A4:Capacity Planning7                 25.14
# 8     A4:Capacity Planning8                 25.14
# 9     A4:Capacity Planning9                 25.14
# 10   A4:Capacity Planning10                 25.15
# 11   A4:Capacity Planning11                 25.15
# 12   A4:Capacity Planning12                 25.15
# 13   A4:Capacity Planning13                 25.15
# 14   A4:Capacity Planning14                 25.16
# 15   A4:Capacity Planning15                 25.16
# 16   A4:Capacity Planning16                 25.16
# 17   A4:Capacity Planning17                 25.17
# ...

# %%
df3
# Out:
#     Time  A4:Capacity Planning0 Temperature  \
# 0      0                          77.294482
# 1      1                          77.287639
# 2      2                          77.285662
# 3      3                          77.295560
# 4      4                          77.299522
# 5      5                          77.300600
# 6      6                          77.301860
# 7      7                          77.305640
# 8      8                          77.311219
# 9      9                          77.317519
# 10    10                          77.324540
# 11    11                          77.332099
# 12    12                          77.340559
# 13    13                          77.351360
# 14    14                          77.365759
# 15    15                          77.384659
# 16    16                          77.408959
# 17    17                          77.438121
# 18    18                          77.470699
# 19    19                          77.504901
# ...

# %%
df3.describe()
# Out:
#             Time  A4:Capacity Planning0 Temperature  \
# count  31.000000                          31.000000
# mean   15.000000                          77.472006
# std     9.092121                           0.192159
# min     0.000000                          77.285662
# 25%     7.500000                          77.308429
# 50%    15.000000                          77.384659
# 75%    22.500000                          77.615600
# max    30.000000                          77.900899
#
#        A4:Capacity Planning1 Temperature  A4:Capacity Planning2 Temperature  \
# count                          31.000000                          31.000000
# mean                           77.451034                          77.448305
# std                             0.201928                           0.209681
# min                            77.237421                          77.227881
# 25%                            77.275491                          77.259830
# ...

# %%
# Checking for missing values: NONE FOUND
#df1.apply(lambda x: sum(x.isnull()), axis = 0)

# %%
# Checking for missing values: NONE FOUND
#df2.apply(lambda x: sum(x.isnull()), axis = 0)

# %%
# Checking for missing values: NONE FOUND
#df3.apply(lambda x: sum(x.isnull()), axis = 0)

# %%
# RIST 10 A4 Capacity

df3['A4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning1 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning2 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning3 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning4 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning5 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning6 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning7 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning8 Temperature'].hist(bins = 15)

# %%
df3['A4:Capacity Planning9 Temperature'].hist(bins = 15)

# %%
# CONPARING FIRST 4's

df3['A4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['B4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['C4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['E4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['F4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['G4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['I4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['J4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['K4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
df3['M4:Capacity Planning0 Temperature'].hist(bins = 15)

# %%
A4B4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning0 Temperature', color='DarkBlue', label='Group 1');
A4E4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning1 Temperature', color='DarkGreen', label='Group 2',ax = A4B4);
A4F4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning2 Temperature', color='DarkRed', label='Group 3',ax = A4B4);
A4G4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning3 Temperature', color='Yellow', label='Group 4',ax = A4B4);
A4I4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning4 Temperature', color='Brown', label='Group 5',ax = A4B4);
A4J4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning5 Temperature', color='Pink', label='Group 6',ax = A4B4);
A4K4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning6 Temperature', color='Purple', label='Group 7',ax = A4B4);
A4M4 = df3.plot.scatter(x='Time', y='A4:Capacity Planning7 Temperature', color='Orange', label='Group 8',ax = A4B4);

A4E5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning8 Temperature', color='Green', label='Group 9',ax = A4B4);
A4F5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning9 Temperature', color='Red', label='Group 10',ax = A4B4);
A4G5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning10 Temperature', color='Black', label='Group 11',ax = A4B4);
A4I5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning11 Temperature', color='Grey', label='Group 12',ax = A4B4);
A4J5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning12 Temperature', color='Blue', label='Group 13',ax = A4B4);
A4K5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning13 Temperature', color='Purple', label='Group 14',ax = A4B4);
A4M5 = df3.plot.scatter(x='Time', y='A4:Capacity Planning14 Temperature', color='Orange', label='Group 15',ax = A4B4);

# %%
file = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/capstone/td.csv')
file
# Out:
#     Time  A4:Capacity Planning0 Temperature  \
# 0      0                          77.294482
# 1      1                          77.287639
# 2      2                          77.285662
# 3      3                          77.295560
# 4      4                          77.299522
# 5      5                          77.300600
# 6      6                          77.301860
# 7      7                          77.305640
# 8      8                          77.311219
# 9      9                          77.317519
# 10    10                          77.324540
# 11    11                          77.332099
# 12    12                          77.340559
# 13    13                          77.351360
# 14    14                          77.365759
# 15    15                          77.384659
# 16    16                          77.408959
# 17    17                          77.438121
# 18    18                          77.470699
# 19    19                          77.504901
# ...

# %%
file2 = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/capstone/r4.csv')
file2
# Out:
#     Time  O13:Capacity Planning0 Temperature  \
# 0      0                           25.312599
# 1      1                           25.312700
# 2      2                           25.313900
# 3      3                           25.316000
# 4      4                           25.320601
# 5      5                           25.334700
# 6      6                           25.372101
# 7      7                           25.440701
# 8      8                           25.539801
# 9      9                           25.661600
# 10    10                           25.796699
# 11    11                           25.937901
# 12    12                           26.078501
# 13    13                           26.213900
# 14    14                           26.329000
# 15    15                           26.410601
# 16    16                           26.451300
# 17    17                           26.441500
# 18    18                           26.377800
# 19    19                           26.280100
# ...

# %%
import xml.etree.ElementTree as ET
import csv

tree = ET.parse("r1.xml")
root = tree.getroot()

# open a file for writing

Resident_data = open('/Users/leonardoroman/Desktop/data_science_projects/capstone/r1.csv', 'w')

# create the csv writer object

csvwriter = csv.writer(Resident_data)
resident_head = []

count = 0
for member in root.findall('Resident'):
    resident = []
    address_list = []
    if count == 0:
        name = member.find('Name').tag
        resident_head.append(name)
        PhoneNumber = member.find('PhoneNumber').tag
        resident_head.append(PhoneNumber)
        EmailAddress = member.find('EmailAddress').tag
        resident_head.append(EmailAddress)
        Address = member[3].tag
        resident_head.append(Address)
        csvwriter.writerow(resident_head)
        count = count + 1

    name = member.find('Name').text
    resident.append(name)
    PhoneNumber = member.find('PhoneNumber').text
    resident.append(PhoneNumber)
    EmailAddress = member.find('EmailAddress').text
    resident.append(EmailAddress)
    Address = member[3][0].text
    address_list.append(Address)
    City = member[3][1].text
    address_list.append(City)
    StateCode = member[3][2].text
    address_list.append(StateCode)
    PostalCode = member[3][3].text
    address_list.append(PostalCode)
    resident.append(address_list)
    csvwriter.writerow(resident)
Resident_data.close()

# %%
file3 = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/capstone/r1.csv')
file3
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-14-3a8f74514ff0> in <module>()
# ----> 1 file3 = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/capstone/r1.csv')
#
# ...

# %%
file4 = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/capstone/r4.csv')
file4
# Out:
#     Time  O13:Capacity Planning0 Temperature  \
# 0      0                           25.312599
# 1      1                           25.312700
# 2      2                           25.313900
# 3      3                           25.316000
# 4      4                           25.320601
# 5      5                           25.334700
# 6      6                           25.372101
# 7      7                           25.440701
# 8      8                           25.539801
# 9      9                           25.661600
# 10    10                           25.796699
# 11    11                           25.937901
# 12    12                           26.078501
# 13    13                           26.213900
# 14    14                           26.329000
# 15    15                           26.410601
# 16    16                           26.451300
# 17    17                           26.441500
# 18    18                           26.377800
# 19    19                           26.280100
# ...

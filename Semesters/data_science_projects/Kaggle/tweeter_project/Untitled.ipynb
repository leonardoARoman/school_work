# %%
import pandas as pd
import numpy as np

file = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/Kaggle/tweeter_project/data_sets/train.csv')

# %%
file
# Out:
#         id  label                                              tweet
# 0        1      0   @user when a father is dysfunctional and is s...
# 1        2      0  @user @user thanks for #lyft credit i can't us...
# 2        3      0                                bihday your majesty
# 3        4      0  #model   i love u take with u all the time in ...
# 4        5      0             factsguide: society now    #motivation
# 5        6      0  [2/2] huge fan fare and big talking before the...
# 6        7      0   @user camping tomorrow @user @user @user @use...
# 7        8      0  the next school year is the year for exams.Ã°Â...
# 8        9      0  we won!!! love the land!!! #allin #cavs #champ...
# 9       10      0   @user @user welcome here !  i'm   it's so #gr8 !
# 10      11      0   Ã¢Â†Â #ireland consumer price index (mom) cl...
# 11      12      0  we are so selfish. #orlando #standwithorlando ...
# 12      13      0  i get to see my daddy today!!   #80days #getti...
# ...

# %%
# No missing values
file.apply(lambda x: sum(x.isnull()), axis = 0)
# Out:
# id       0
# label    0
# tweet    0
# dtype: int64

# %%
# number of normal tweets >> hate speech tweets
file['label'].hist(bins = 20)

# %%
import pandas as pd
import numpy as np
file = pd.read_csv('/Users/leonardoroman/Desktop/data_science_projects/Kaggle/tweeter_project/data_sets/train.csv')
